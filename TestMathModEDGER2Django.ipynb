# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanziaur/EDGEICT/blob/main/TestMathModEDGER2Django.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/rahmanziaur/EDGEICTLive/refs/heads/main/Calculator.py
# Out:
# --2025-01-04 10:47:15--  https://raw.githubusercontent.com/rahmanziaur/EDGEICTLive/refs/heads/main/Calculator.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 138 [text/plain]
# Saving to: ‘Calculator.py’
#
# Calculator.py       100%[===================>]     138  --.-KB/s    in 0s
#
# 2025-01-04 10:47:15 (2.27 MB/s) - ‘Calculator.py’ saved [138/138]

# %%
from EDGEICTLive.Calculator import subtract

# %%
subtract(23,34)
# Out:
# 11

# %%
calc.add(12, 23)
# Out:
# 35

# %%
import math

print (math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# **Printing the value of *e* upto a given digit**

# %%
# https://github.com/microice333/Python-projects/blob/master/n_digit_e.py
# find e to nth digit by brothers' formulae: http://www.intmath.com/exponential-logarithmic-functions/calculating-e.php
import decimal


def factorial(n):
    factorials = [1]
    for i in range(1, n + 1):
        factorials.append(factorials[i - 1] * i)
    return factorials


def compute_e(n):
    decimal.getcontext().prec = n + 1
    e = 2
    factorials = factorial(2 * n + 1)
    for i in range(1, n + 1):
        counter = 2 * i + 2
        denominator = factorials[2 * i + 1]
        e += decimal.Decimal(counter / denominator)
    return e


while True:
    n = int(input("Please type number between 0-10000: "))
    if n >= 0 and n <= 10000:
        break

print(str(compute_e(n))[:n + 1])
# Out:
# Please type number between 0-10000: 9899
# 2....

# %%
# Define the big number as a string
big_number = "2...."

# Remove the decimal point
big_number_without_decimal = big_number.replace(".", "")

# Count the digits
digit_count = len(big_number_without_decimal)

# Print the result
print(f"The number of digits in the big number is: {digit_count}")
# Out:
# The number of digits in the big number is: 10001

# %%
import decimal


def factorial(n):
    """Efficiently compute the factorial using an iterative approach."""
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result


def compute_e(n):
    """Compute the value of e using the series expansion."""
    decimal.getcontext().prec = n + 2  # Set precision to n digits + 2 for safety
    e = decimal.Decimal(0)
    i = 0

    while True:
        term = decimal.Decimal(1) / decimal.Decimal(factorial(i))
        if term < decimal.Decimal(10) ** -(n + 1):  # Stop when the term is too small to affect precision
            break
        e += term
        i += 1

    return e


# Input validation for n
while True:
    try:
        n = int(input("Enter the number of decimal places to compute e (e.g., 1000, 5000, etc.): "))
        if n > 0:
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter an integer.")

# Compute and print e
e_value = compute_e(n)
print(f"The value of e to {n} decimal places is:")
print(str(e_value)[:n + 2])  # Ensure the output is limited to n decimal places
# Out:
# Enter the number of decimal places to compute e (e.g., 1000, 5000, etc.): 10000
# The value of e to 10000 decimal places is:
# 2....

# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2025-01-04 11:21:05.473776

# %%
import datetime

x = datetime.datetime(2024, 12, 25)
# "%d-%b-%Y"
formatted_date = x.strftime("%d-%b-%Y")

print(formatted_date)

print(x)
# Out:
# 25-Dec-2024
# 2024-12-25 00:00:00
